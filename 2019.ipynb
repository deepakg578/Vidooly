# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
pd.set_option('display.max_columns',None)

# %%
data17 = pd.read_csv('2019.csv')

# %%
data17.head()
# Out:
#    Reg.No  Reg.Date                               First Party  \
# 0       7  1/1/2019                              S C KHURANA
# 1      11  2/1/2019                      RAJESH KUMAR BHASIN
# 2      20  2/1/2019                           SANDEEP ARVIND
# 3      36  3/1/2019  LIKHA SAAYA THRU ATT MANOJ KUMAR GULATI
# 4      39  3/1/2019                           VISHAL JAIRATH
#
#                                         Second Party  \
# 0                                       AJAY VISHAL
# 1                                        MIN HO KIM
# 2                                    RADHALAKSHMI R
# 3                                 KANUKPRIYA GULATI
# 4  ITHIKIA HEALTH SCIENCES LLP THRU CHAND RATAN D...
#
#                                     Property Address            Area  \
# 0                House No. B-3/93,Safdarjung Enclave   100 Sq. Meter
# 1             House No. A1/161 FF,Safdarjung Enclave   2050 Sq. Feet
# 2  House No. A-1/257 F/F REAR PORTION,Safdarjung ...   1000 Sq. Feet
# 3     House No. FF PROP NO A-1/62,Safdarjung Enclave    443 Sq. Yard
# 4  House No. ENTIRE BASEMENT AND ENTIRE GF, Road ...  2000 Sq. Meter
#
#                                  Deed Type Property Type
# 0   LEASE,LEASE WITH SECURITY UPTO 5 YEARS   Residential
# 1   LEASE,LEASE WITH SECURITY UPTO 5 YEARS   Residential
# 2                 LEASE,LEASE UPTO 5 YEARS   Residential
# 3                 SALE,SALE WITHIN MC AREA   Residential
# 4  LEASE,LEASE WITH SECURITY UPTO 10 YEARS    Commercial

# %%
data17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 8 columns):
# Reg.No              193 non-null int64
# Reg.Date            193 non-null object
# First Party         193 non-null object
# Second Party        192 non-null object
# Property Address    193 non-null object
# Area                193 non-null object
# Deed Type           193 non-null object
# Property Type       193 non-null object
# dtypes: int64(1), object(7)
# memory usage: 12.1+ KB

# %%
from datetime import datetime,date

data17['Reg.Date'] = pd.to_datetime(data17['Reg.Date'],dayfirst=True)
L = ['year', 'month', 'day', 'dayofweek', 'dayofyear', 'weekofyear', 'quarter']

data17 = data17.join(pd.concat((getattr(data17['Reg.Date'].dt, i).rename(i) for i in L), axis=1))

# %%
L = []
for i in data17['Area']:
    if i.split()[2] =='Feet':
        L.append(float(i.split()[0])/10.764)
    elif i.split()[2] =='Yard':
        L.append(float(i.split()[0])/1.1960)
    else:
        L.append(i.split()[0])
data17['Area'] = L    
data17.rename({'Area': 'Area(sq m)', 'b': 'Y'}, axis=1, inplace = True)

# %%
data17.head(85)
# Out:
#     Reg.No   Reg.Date                                        First Party  \
# 0        7 2019-01-01                                       S C KHURANA
# 1       11 2019-01-02                               RAJESH KUMAR BHASIN
# 2       20 2019-01-02                                    SANDEEP ARVIND
# 3       36 2019-01-03           LIKHA SAAYA THRU ATT MANOJ KUMAR GULATI
# 4       39 2019-01-03                                    VISHAL JAIRATH
# 5       41 2019-01-03                                       TANUJ KAPUR
# 6       57 2019-01-04                                RAVI KANT BHARDWAJ
# 7       58 2019-01-04                                       ANJALI BAHL
# 8       61 2019-01-04              EXPRESS TOWERS PVT LTD THRU R.C GOEL
# 9       72 2019-01-04                   SUDESH KOHLI THRU AVINASH KOHLI
# 10      81 2019-01-07                                      NEELU TANNAN
# 81    1281 2019-03-15                                      ANITA THAPAR
# 82    1287 2019-03-15                          GAURAV NIGAM,KUSUM NIGAM
# 83    1321 2019-03-22                                   KANWALJIT SINGH
# 84    1330 2019-03-22                     SUDESH SAWHNEY,KANIKA SAWHNEY
#
#                                          Second Party  \
# 0                                        AJAY VISHAL
# 1                                         MIN HO KIM
# 2                                     RADHALAKSHMI R
# 3                                  KANUKPRIYA GULATI
# 4   ITHIKIA HEALTH SCIENCES LLP THRU CHAND RATAN D...
# 5                                ANUJ BAHRI MALHOTRA
# 6                                       ASHOK SHARMA
# 7                     SNEH LATA BHARGAV,KUNWAR VIKAS
# 8          VALMAX BUILDCON PVT LTD THRU MUNISH GOYAL
# 9                                MOHD REHAN SIDDIQUE
# 10                                   TOMOHIRO NARUMI
# 11                            LAKSHMAN CHANDRA ANAND
# 12                    ANKUR SHRIVASTAVA,AKRITI KHARE
# 13                          GILEY SINGH,AKASH SHARMA
# 14              SUDARSHAN SINGH GULATI,SHAMMI GULATI
# 15                                     PRATIMA NAGAR
# 16          INDUSIND BANK LIMITED THRU LOVKESH GUPTA
# 17                                    RAJINDER SINGH
# 18                                    RAJINDER SINGH
# 19                                     BRIJESH KUMAR
# 20                                RAVI PRKASH NEHRAW
# 21                              GURMEET SINGH SIDANA
# 22                        RAJEEV RANJAN,SWATHI SENAN
# 23                                       JAYA DUSEZA
# 24                                        IDRISH ALI
# 25                   MUNISH KUMAR GUPTA,NITIKA GUPTA
# 26                                SUSHIL KUMAR DUBEY
# 27                                RUPAL RAJESH DALAL
# 28        DAIRY CHEM CORPORATION THRU SIDHARTH GUPTA
# 29             VINITA KALRA,SHRI PARVEEN KUMAR KALRA
# ..                                                ...
# 55                                     ANJANA SHARMA
# 56          ONCQUEST LABORATORIES LTD THRU RAVI GAUR
# 57  IRIS PARK LEISURES PVT LTD THRU VARUN PRAKASH ...
# 58                                   A VENKATACHALAM
# 59  UTRACON STRUCTURAL SYSTEMS PVT LTD THRU JAYAKU...
# 60                      MANSAK SHISHAK,SORUN SHISHAK
# 61                                          P K KAUL
# 62                                     MANISH BHALLA
# 63                                       ASHOK KUMAR
# 64                                     PRASHANT JAIN
# 65                                      SUDHIR SINGH
# 66                                  SANDEEP SAHAJPAL
# 67                                    KRISHNANUNNI U
# 68                           VIPUL GUPTA,POOJA GUPTA
# 69                          SADHNA SHUKLA,UMA SHARMA
# 70                                JAY BHAVIN KOTHARI
# 71                                     GAURAV BHASIN
# 72                                       GEETA SINGH
# 73                                      MANMEET KAUR
# 74                                   CHARANJIT SINGH
# 75                                     KULDEEP KUMAR
# 76             ASHOK KUMAR GANDHI,VIPIN KUMAR GANDHI
# 77                            DOGIPARTHI SWAMY GUPTA
# 78                                        NEHA ARORA
# 79  PARUL GOEL,AJAY KUMAR SHARMA,RAJESH KUMAR PASWAN
# 80                                        NEERA PURI
# 81                                        RAHUL GERA
# 82  LOMBARDI ENGINEERING INDIA PVT LTD THRU HEMANT...
# 83                                     JAGDEEP SINGH
# 84                                    AMARESH PODDER
#
#                                      Property Address Area(sq m)  \
# 0                 House No. B-3/93,Safdarjung Enclave        100
# 1              House No. A1/161 FF,Safdarjung Enclave     190.45
# 64      2   27          2         58           9        1
# 65      2   27          2         58           9        1
# 66      2   27          2         58           9        1
# 67      3    1          4         60           9        1
# 68      3    6          2         65          10        1
# 69      3    6          2         65          10        1
# 70      3    6          2         65          10        1
# 71      3    6          2         65          10        1
# 72      3    7          3         66          10        1
# 73      3    7          3         66          10        1
# 74      3    7          3         66          10        1
# 75      3    7          3         66          10        1
# 76      3    8          4         67          10        1
# 77      3    8          4         67          10        1
# 78      3    8          4         67          10        1
# 79      3   14          3         73          11        1
# 80      3   15          4         74          11        1
# 81      3   15          4         74          11        1
# 82      3   15          4         74          11        1
# 83      3   22          4         81          12        1
# 84      3   22          4         81          12        1
#
# [85 rows x 15 columns]

# %% [markdown]
# # Extraction of LAT and LON

# %%
import requests
RETURN_FULL_RESULTS = False
API = 'AIzaSyClmuC_FAgQ9ZBntFnUMuhpMVDsIabhD-c'

def get_google_results(address, api_key=None, return_full_response=False):
    
    # Set up your Geocoding url
    geocode_url = "https://maps.googleapis.com/maps/api/geocode/json?address={}".format(address)
    if api_key is not None:
        geocode_url = geocode_url + "&key={}".format(api_key)
        
    # Ping google for the reuslts:
    results = requests.get(geocode_url)
    # Results will be in JSON format - convert to dict using requests functionality
    results = results.json()
    
    # if there's no results or an error, return empty results.
    if len(results['results']) == 0:
        output = {
            "formatted_address" : None,
            "latitude": None,
            "longitude": None,
            "accuracy": None,
            "google_place_id": None,
            "type": None,
            "postcode": None
        }
    else:    
        answer = results['results'][0]
        output = {
            "formatted_address" : answer.get('formatted_address'),
            "latitude": answer.get('geometry').get('location').get('lat'),
            "longitude": answer.get('geometry').get('location').get('lng'),
            "accuracy": answer.get('geometry').get('location_type'),
            "google_place_id": answer.get("place_id"),
            "type": ",".join(answer.get('types')),
            "postcode": ",".join([x['long_name'] for x in answer.get('address_components') 
                                  if 'postal_code' in x.get('types')])
        }
        
    # Append some other details:    
    output['input_string'] = address
    output['number_of_results'] = len(results['results'])
    output['status'] = results.get('status')
    if return_full_response is True:
        output['response'] = results
    
    return output

# %%
get_google_results("House No. AB-9 SHOP NO-3 G/F COMMUNITY CENTRE,Safdarjung Enclave", API, RETURN_FULL_RESULTS)
# Out:
# {'accuracy': None,
#  'formatted_address': None,
#  'google_place_id': None,
#  'input_string': 'House No. AB-9 SHOP NO-3 G/F COMMUNITY CENTRE,Safdarjung Enclave',
#  'latitude': None,
#  'longitude': None,
#  'number_of_results': 0,
#  'postcode': None,
#  'status': 'OVER_QUERY_LIMIT',
#  'type': None}

# %%
lat = []
lon = []
for indx,i in enumerate(data17['Property Address']):
    lat.append(get_google_results(i, API, RETURN_FULL_RESULTS)['latitude'])
    lon.append(get_google_results(i, API, RETURN_FULL_RESULTS)['longitude'])

# %%
data17['Lat'] = lat
data17['Lon'] = lon

# %%
data17['Lat'].fillna(data17['Lat'].mean(),inplace=True)
data17['Lon'].fillna(data17['Lon'].mean(),inplace=True)
data17[['Lat', 'Lon']].head()
# Out:
#          Lat        Lon
# 0  28.564726  77.194916
# 1  28.567046  77.197868
# 2  28.564726  77.194916
# 3  28.569252  77.197986
# 4  28.564726  77.194916

# %%
data17.to_csv('2019NEW.csv',index=False)

# %%
#import gmaps
#gmaps.configure(api_key='AIzaSyClmuC_FAgQ9ZBntFnUMuhpMVDsIabhD-c')

# %%
#import gmaps
# Use google maps api
#gmaps.configure(api_key='AIzaSyClmuC_FAgQ9ZBntFnUMuhpMVDsIabhD-c') # Fill in with your API key

#Get the locations from the data set
#locations = data17[['Lat', 'Lon']]
#Get the magnitude from the data
#weights = data17['Area']
#Set up your map
#delhi_coordinates = (28.5647, 77.1949)
#fig = gmaps.figure(center=delhi_coordinates,zoom_level=12)
#fig.add_layer(gmaps.heatmap_layer(locations, weights=weights))
#fig

# %%
import folium
from folium import plugins
from folium.plugins import HeatMap


map_hooray = folium.Map(location=[28.5647, 77.1949],
                    zoom_start = 13) 

# Ensure you're handing it floats
data17['Lat'] = data17['Lat'].astype(float)
data17['Lon'] = data17['Lon'].astype(float)


heat_df = data17[['Lat', 'Lon']]

# List comprehension to make out list of lists
heat_data = [[row['Lat'],row['Lon']] for index, row in heat_df.iterrows()]

# Plot it on the map
HeatMap(heat_data).add_to(map_hooray)

# Display the map
map_hooray
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
my_cord = [28.5647, 77.1949]

#Create the map
my_map = folium.Map(location = my_cord, zoom_start = 16)

# %%
for i in range(0,data17.shape[0]):
    folium.Marker(heat_data[i], popup = {'Reg NO' : data17['Reg.No'][i],
                                         'Reg.Date' :  data17['Reg.Date'][i],
                                         'Area': data17['Area(sq m)'][i],
                                         'Deed Type' : data17['Deed Type'][i],
                                         'Property Type':data17['Property Type'][i]}).add_to(my_map)

# %%
display(my_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
data17.head()
# Out:
#    Reg.No   Reg.Date                               First Party  \
# 0       7 2019-01-01                              S C KHURANA
# 1      11 2019-01-02                      RAJESH KUMAR BHASIN
# 2      20 2019-01-02                           SANDEEP ARVIND
# 3      36 2019-01-03  LIKHA SAAYA THRU ATT MANOJ KUMAR GULATI
# 4      39 2019-01-03                           VISHAL JAIRATH
#
#                                         Second Party  \
# 0                                       AJAY VISHAL
# 1                                        MIN HO KIM
# 2                                    RADHALAKSHMI R
# 3                                 KANUKPRIYA GULATI
# 4  ITHIKIA HEALTH SCIENCES LLP THRU CHAND RATAN D...
#
#                                     Property Address Area(sq m)  \
# 0                House No. B-3/93,Safdarjung Enclave        100
# 1             House No. A1/161 FF,Safdarjung Enclave     190.45
# 2  House No. A-1/257 F/F REAR PORTION,Safdarjung ...    92.9023
# 3     House No. FF PROP NO A-1/62,Safdarjung Enclave    370.401
# 4  House No. ENTIRE BASEMENT AND ENTIRE GF, Road ...       2000
#
#                                  Deed Type Property Type  year  month  day  \
# 0   LEASE,LEASE WITH SECURITY UPTO 5 YEARS   Residential  2019      1    1
# 1   LEASE,LEASE WITH SECURITY UPTO 5 YEARS   Residential  2019      1    2
# 2                 LEASE,LEASE UPTO 5 YEARS   Residential  2019      1    2
# 3                 SALE,SALE WITHIN MC AREA   Residential  2019      1    3
# 4  LEASE,LEASE WITH SECURITY UPTO 10 YEARS    Commercial  2019      1    3
#
#    dayofweek  dayofyear  weekofyear  quarter        Lat        Lon
# 0          1          1           1        1  28.564726  77.194916
# 1          2          2           1        1  28.567046  77.197868
# 2          2          2           1        1  28.564726  77.194916
# 3          3          3           1        1  28.569252  77.197986
# 4          3          3           1        1  28.564726  77.194916
